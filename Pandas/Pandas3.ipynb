# %% [markdown]
# <h1 style="color:blue">Pivot basics</h1>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("weather.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index='city',columns='date')
# Out:
#          temperature                   humidity
# date        5/1/2017 5/2/2017 5/3/2017 5/1/2017 5/2/2017 5/3/2017
# city
# beijing           80       77       79       26       30       35
# mumbai            75       78       82       80       83       85
# new york          65       66       68       56       58       60

# %%
df.T
# Out:
#                     0         1         2         3         4         5  \
# date         5/1/2017  5/2/2017  5/3/2017  5/1/2017  5/2/2017  5/3/2017
# city         new york  new york  new york    mumbai    mumbai    mumbai
# temperature        65        66        68        75        78        82
# humidity           56        58        60        80        83        85
#
#                     6         7         8
# date         5/1/2017  5/2/2017  5/3/2017
# city          beijing   beijing   beijing
# temperature        80        77        79
# humidity           26        30        35

# %%
df.pivot(index='city',columns='date')["temperature"]
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         80        77        79
# mumbai          75        78        82
# new york        65        66        68

# %%
df.pivot(index='city',columns='date')["temperature"].to_csv("pivot.csv")

# %%
df.pivot(index='city',columns='date',values="humidity") # return a dataframe
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
df.pivot(index='date',columns='city')
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
df.pivot(index='date',columns='city').to_csv("pivotCity.csv")

# %%
df.pivot(index='humidity',columns='city')
# Out:
#               date                     temperature
# city       beijing    mumbai  new york     beijing mumbai new york
# humidity
# 26        5/1/2017       NaN       NaN        80.0    NaN      NaN
# 30        5/2/2017       NaN       NaN        77.0    NaN      NaN
# 35        5/3/2017       NaN       NaN        79.0    NaN      NaN
# 56             NaN       NaN  5/1/2017         NaN    NaN     65.0
# 58             NaN       NaN  5/2/2017         NaN    NaN     66.0
# 60             NaN       NaN  5/3/2017         NaN    NaN     68.0
# 80             NaN  5/1/2017       NaN         NaN   75.0      NaN
# 83             NaN  5/2/2017       NaN         NaN   78.0      NaN
# 85             NaN  5/3/2017       NaN         NaN   82.0      NaN

# %% [markdown]
# ## <h1 style="color:blue">Pivot Table</h1>

# %%
df = pd.read_csv("weather2.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
df.pivot_table(index="city",columns="date")
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %% [markdown]
# <h2 style="color:brown">Margins</h2>

# %%
df.pivot_table(index="city",columns="date",aggfunc=np.sum)
# Out:
# <ipython-input-21-8487d03135d1>:1: FutureWarning: The provided callable <function sum at 0x7b69be5b4670> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(index="city",columns="date",aggfunc=np.sum)
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai        163      111         153      162
# new york      110      122         126      142

# %%
df.pivot_table(index="city",columns="date", margins=True,aggfunc=np.sum)
# Out:
# <ipython-input-20-32a8d397c9bf>:1: FutureWarning: The provided callable <function sum at 0x7b69be5b4670> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(index="city",columns="date", margins=True,aggfunc=np.sum)
# <ipython-input-20-32a8d397c9bf>:1: FutureWarning: The provided callable <function sum at 0x7b69be5b4670> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(index="city",columns="date", margins=True,aggfunc=np.sum)
# <ipython-input-20-32a8d397c9bf>:1: FutureWarning: The provided callable <function sum at 0x7b69be5b4670> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(index="city",columns="date", margins=True,aggfunc=np.sum)
#          humidity               temperature
# date     5/1/2017 5/2/2017  All    5/1/2017 5/2/2017  All
# city
# mumbai        163      111  274         153      162  315
# new york      110      122  232         126      142  268
# All           273      233  506         279      304  583

# %%
df.pivot_table(index="city",columns="date",aggfunc=np.sum)
# Out:
# <ipython-input-22-8487d03135d1>:1: FutureWarning: The provided callable <function sum at 0x7b69be5b4670> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(index="city",columns="date",aggfunc=np.sum)
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai        163      111         153      162
# new york      110      122         126      142

# %%
df.pivot_table(index="city",columns="date",aggfunc=np.sum)["humidity"]
# Out:
# <ipython-input-23-f250aaaa7b03>:1: FutureWarning: The provided callable <function sum at 0x7b69be5b4670> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(index="city",columns="date",aggfunc=np.sum)["humidity"]
# date      5/1/2017  5/2/2017
# city
# mumbai         163       111
# new york       110       122

# %% [markdown]
# <h2 style="color:brown">Grouper</h2>

# %%
df = pd.read_csv("weather3.csv")
df
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
print(type(df["date"][0]))
df['date'] = pd.to_datetime(df['date'])
# Out:
# <class 'str'>

# %%
df
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-12-03  new york           25        51

# %%
type(df["date"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.pivot_table(index=pd.Grouper(freq='W',key='date'),columns='city')
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-07  56.666667   65.333333
# 2017-12-03  51.000000   27.666667

# %%
df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
# <ipython-input-30-f80a3426c14a>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %%
df.pivot_table(index=pd.Grouper(freq='Y',key='date'),columns='city')
# Out:
# <ipython-input-31-38b22e6c07e8>:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df.pivot_table(index=pd.Grouper(freq='Y',key='date'),columns='city')
#              humidity temperature
# city         new york    new york
# date
# 2017-12-31  53.833333        46.5

# %%
df.pivot_table(index=pd.Grouper(freq='Y',key='date'),columns='city', aggfunc=np.sum)
# Out:
# <ipython-input-32-bda298526a07>:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df.pivot_table(index=pd.Grouper(freq='Y',key='date'),columns='city', aggfunc=np.sum)
# <ipython-input-32-bda298526a07>:1: FutureWarning: The provided callable <function sum at 0x7b69be5b4670> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(index=pd.Grouper(freq='Y',key='date'),columns='city', aggfunc=np.sum)
#            humidity temperature
# city       new york    new york
# date
# 2017-12-31      323         279

# %%
df.pivot_table(index=pd.Grouper(freq='Y',key='date'),columns='city', aggfunc=np.sum)
# Out:
# <ipython-input-33-bda298526a07>:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df.pivot_table(index=pd.Grouper(freq='Y',key='date'),columns='city', aggfunc=np.sum)
# <ipython-input-33-bda298526a07>:1: FutureWarning: The provided callable <function sum at 0x7b69be5b4670> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(index=pd.Grouper(freq='Y',key='date'),columns='city', aggfunc=np.sum)
#            humidity temperature
# city       new york    new york
# date
# 2017-12-31      323         279

# %% [markdown]
# ## Pandas Time Series Analysis Tutorial: Handling Holidays

# %%
df = pd.read_csv("aapl_no_dates.csv")
df.head()
# Out:
#      Open    High     Low   Close    Volume
# 0  144.88  145.30  143.10  143.50  14277848
# 1  143.69  144.79  142.72  144.09  21569557
# 2  143.02  143.50  142.41  142.73  24128782
# 3  142.90  144.75  142.90  144.18  19201712
# 4  144.11  145.95  143.37  145.06  21090636

# %%
df.shape
# Out:
# (14, 5)

# %%
rng= pd.date_range(start="7/1/2017", end="7/21/2017", freq='B') # B => business days
rng
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-04', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# ### Using CustomBusinessDay to generate US holidays calendar frequency

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

us_cal = CustomBusinessDay(calendar=USFederalHolidayCalendar())

rng = pd.date_range(start="7/1/2017",end="7/23/2017", freq=us_cal)
rng
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-05', '2017-07-06', '2017-07-07',
#                '2017-07-10', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-14', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='C')

# %%
df.set_index(rng,inplace=True)
df.head()
# Out:
#               Open    High     Low   Close    Volume
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-10  144.11  145.95  143.37  145.06  21090636

# %% [markdown]
# ### AbstractHolidayCalendar

# %%
from pandas.tseries.holiday import AbstractHolidayCalendar, nearest_workday, Holiday
class myCalendar(AbstractHolidayCalendar):
    rules = [
        Holiday('My Birth Day', month=3, day=31),# observance=nearest_workday),
    ]
my_bday = CustomBusinessDay(calendar=myCalendar())
pd.date_range('3/25/2017','4/30/2017',freq=my_bday)
# Out:
# DatetimeIndex(['2017-03-27', '2017-03-28', '2017-03-29', '2017-03-30',
#                '2017-04-03', '2017-04-04', '2017-04-05', '2017-04-06',
#                '2017-04-07', '2017-04-10', '2017-04-11', '2017-04-12',
#                '2017-04-13', '2017-04-14', '2017-04-17', '2017-04-18',
#                '2017-04-19', '2017-04-20', '2017-04-21', '2017-04-24',
#                '2017-04-25', '2017-04-26', '2017-04-27', '2017-04-28'],
#               dtype='datetime64[ns]', freq='C')

# %% [markdown]
# ### CustomBusinessDay
# Weekend in egypt is Friday and Saturday. Sunday is just a normal weekday and you can handle this custom week schedule using CystomBysinessDay with weekmask as shown below

# %%
egypt_weekdays = "Sun Mon Tue Wed Thu"

b = CustomBusinessDay(weekmask=egypt_weekdays)

pd.date_range(start="7/1/2017",periods=20,freq=b)
# Out:
# DatetimeIndex(['2017-07-02', '2017-07-03', '2017-07-04', '2017-07-05',
#                '2017-07-06', '2017-07-09', '2017-07-10', '2017-07-11',
#                '2017-07-12', '2017-07-13', '2017-07-16', '2017-07-17',
#                '2017-07-18', '2017-07-19', '2017-07-20', '2017-07-23',
#                '2017-07-24', '2017-07-25', '2017-07-26', '2017-07-27'],
#               dtype='datetime64[ns]', freq='C')

# %% [markdown]
# #### You can also add holidays to this custom business day frequency

# %%
b = CustomBusinessDay(holidays=['2017-07-04', '2017-07-10'], weekmask=egypt_weekdays)
pd.date_range(start="7/1/2017",periods=20,freq=b)
# Out:
# DatetimeIndex(['2017-07-02', '2017-07-03', '2017-07-05', '2017-07-06',
#                '2017-07-09', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-16', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-23', '2017-07-24', '2017-07-25',
#                '2017-07-26', '2017-07-27', '2017-07-30', '2017-07-31'],
#               dtype='datetime64[ns]', freq='C')

# %%
from datetime import datetime
dt = datetime(2017,7,9)
dt
# Out:
# datetime.datetime(2017, 7, 9, 0, 0)

# %%
dt + 1*b
# Out:
# Timestamp('2017-07-11 00:00:00')
