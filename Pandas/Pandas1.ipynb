# %%
import pandas as pd

# %%
data = pd.read_csv("nyc.csv")
data
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0                10           8.0               0           5       NaN
# 1                10           7.0               0           3       NaN
# 2                10           8.0               0           1       NaN
# 3                10           9.0               0           3       NaN
# 4                10           5.0               0           0       NaN
# 5                10           4.0               0           0       NaN
# 6                10           2.0               0           3       NaN
# 7                10           4.0               0           8       NaN
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 10               10           NaN               0           1       NaN
# 11               10           6.0               T           4       NaN
# 12               10          10.0               0           0       NaN
# 13               10           5.0               T           7       NaN
# 14                9           5.0               T           2       NaN
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1       NaN
# 19               10           6.0               0           2       NaN
# 20               10           6.0               0           1       NaN
# 21                9           NaN            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2       NaN
# 25               10           7.0               0           2       NaN
# 26               10           7.0               T           3      Rain
# 27               10           5.0               0           1       NaN
# 28               10           8.0               0           4       NaN
# 29               10           7.0               0           0       NaN
# 30               10           5.0               0           0       NaN
#
#     WindDirDegrees
# 0              281
# 1              275
# 2              277
# 3              345
# 4              333
# 5              259
# 6              293
# 7               79
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
## EDA   Explore data

data.shape
# Out:
# (31, 11)

# %%
data.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
data.columns.to_list()
# Out:
# ['EST',
#  'Temperature',
#  'DewPoint',
#  'Humidity',
#  'Sea Level PressureIn',
#  'VisibilityMiles',
#  'WindSpeedMPH',
#  'PrecipitationIn',
#  'CloudCover',
#  'Events',
#  'WindDirDegrees']

# %%
list(data.columns)
# Out:
# ['EST',
#  'Temperature',
#  'DewPoint',
#  'Humidity',
#  'Sea Level PressureIn',
#  'VisibilityMiles',
#  'WindSpeedMPH',
#  'PrecipitationIn',
#  'CloudCover',
#  'Events',
#  'WindDirDegrees']

# %%
data.columns[0]
# Out:
# 'EST'

# %%
data.columns[1]
# Out:
# 'Temperature'

# %%
data.Temperature
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
##
data["Temperature"]
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
data[["Temperature"]]
# Out:
#     Temperature
# 0            38
# 1            36
# 2            40
# 3            25
# 4            20
# 5            33
# 6            39
# 7            39
# 8            44
# 9            50
# 10           33
# 11           35
# 12           26
# 13           30
# 14           43
# 15           47
# 16           36
# 17           25
# 18           22
# 19           32
# 20           31
# 21           26
# 22           26
# 23           28
# 24           34
# 25           43
# 26           41
# 27           37
# 28           36
# 29           34
# 30           46

# %%
data.Temperature.min()
# Out:
# 20

# %%
data.Temperature.max()
# Out:
# 50

# %%
data.Temperature.mean()
# Out:
# 34.67741935483871

# %%
data.Temperature.std()
# Out:
# 7.639315400279415

# %%
data.Temperature.median()
# Out:
# 35.0

# %%
data.Temperature.mode()
# Out:
# 0    26
# 1    36
# Name: Temperature, dtype: int64

# %%
data.Temperature.var()
# Out:
# 58.35913978494624

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.8+ KB

# %%
data.dtypes
# Out:
# EST                      object
# Temperature               int64
# DewPoint                  int64
# Humidity                  int64
# Sea Level PressureIn    float64
# VisibilityMiles           int64
# WindSpeedMPH            float64
# PrecipitationIn          object
# CloudCover                int64
# Events                   object
# WindDirDegrees            int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# EST                      0
# Temperature              0
# DewPoint                 0
# Humidity                 0
# Sea Level PressureIn     0
# VisibilityMiles          0
# WindSpeedMPH             3
# PrecipitationIn          0
# CloudCover               0
# Events                  22
# WindDirDegrees           0
# dtype: int64

# %%
data.Temperature.dtype
# Out:
# dtype('int64')

# %%
data.Temperature.max()
# Out:
# 50

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.8+ KB

# %%
data.Temperature = data.Temperature.astype("int8")

# %%
data.Temperature.dtype
# Out:
# dtype('int8')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int8
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(2), int64(5), int8(1), object(3)
# memory usage: 2.6+ KB

# %%
for i in data.Temperature:
  if i> 30:
    print(i)
# Out:
# 38
# 36
# 40
# 33
# 39
# 39
# 44
# 50
# 33
# 35
# 43
# 47
# 36
# 32
# 31
# 34
# 43
# 41
# 37
# 36
# 34
# 46

# %%
counter = 0
for i in data.Events:
  if i == "Rain":
    counter = counter + 1
print(counter)
# Out:
# 4

# %%
data [ data.Temperature > 40]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 14                9           5.0               T           2    NaN
# 15                8           7.0            0.24           7   Rain
# 25               10           7.0               0           2    NaN
# 26               10           7.0               T           3   Rain
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 8               76
# 9              109
# 14             101
# 15             340
# 25             244
# 26             311
# 30             241

# %%
data [ data.Temperature > 40].Temperature
# Out:
# 8     44
# 9     50
# 14    43
# 15    47
# 25    43
# 26    41
# 30    46
# Name: Temperature, dtype: int8

# %%
data [ data.Temperature > 40] ["EST"].tolist()
# Out:
# ['1/9/2016',
#  '1/10/2016',
#  '1/15/2016',
#  '1/16/2016',
#  '1/26/2016',
#  '1/27/2016',
#  '1/31/2016']

# %%
data[data.Events == "Rain"]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311

# %%
len(data[data.Events == "Rain"])
# Out:
# 4

# %% [markdown]
# ### **Slicing**

# %%
data[:2]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
#
#    WindDirDegrees
# 0             281
# 1             275

# %%
# all data
data[:]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0                10           8.0               0           5       NaN
# 1                10           7.0               0           3       NaN
# 2                10           8.0               0           1       NaN
# 3                10           9.0               0           3       NaN
# 4                10           5.0               0           0       NaN
# 5                10           4.0               0           0       NaN
# 6                10           2.0               0           3       NaN
# 7                10           4.0               0           8       NaN
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 10               10           NaN               0           1       NaN
# 11               10           6.0               T           4       NaN
# 12               10          10.0               0           0       NaN
# 13               10           5.0               T           7       NaN
# 14                9           5.0               T           2       NaN
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1       NaN
# 19               10           6.0               0           2       NaN
# 20               10           6.0               0           1       NaN
# 21                9           NaN            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2       NaN
# 25               10           7.0               0           2       NaN
# 26               10           7.0               T           3      Rain
# 27               10           5.0               0           1       NaN
# 28               10           8.0               0           4       NaN
# 29               10           7.0               0           0       NaN
# 30               10           5.0               0           0       NaN
#
#     WindDirDegrees
# 0              281
# 1              275
# 2              277
# 3              345
# 4              333
# 5              259
# 6              293
# 7               79
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
data[:5]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
data[10:20]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 10               10           NaN               0           1       NaN
# 11               10           6.0               T           4       NaN
# 12               10          10.0               0           0       NaN
# 13               10           5.0               T           7       NaN
# 14                9           5.0               T           2       NaN
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1       NaN
# 19               10           6.0               0           2       NaN
#
#     WindDirDegrees
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302

# %%
data.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
data.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
data.tail(7)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 24               10           3.0               0           2    NaN
# 25               10           7.0               0           2    NaN
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
data.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# 50%          10.000000      6.500000    3.000000      281.000000
# 75%          10.000000      8.000000    4.500000      300.000000
# max          10.000000     16.000000    8.000000      345.000000

# %%
onlinedata =pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')
onlinedata
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# ## Different Ways Of Creating Dataframe

# %%
## Using CSV

df = pd.read_csv("weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
## Using excel
df=pd.read_excel("weather_data.xls") # sheet name
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
## Using dictionary

weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'windspeed': [6,7,2],
    'event': ['Rain', 'Sunny', 'Snow']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
## Using tuples list

weather_data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
## Using list of dictionaries
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},

]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},

]
df = pd.DataFrame(data=weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## DataFrame Basics Tutorial

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Sunny', 'Sunny']
}

# %%
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (6, 4)

# %%
newdf = df[2:5]
newdf
# Out:
#         day  temperature  windspeed  event
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny

# %%
newdf =df.iloc[2:5 , 0:-1]
newdf
# Out:
#         day  temperature  windspeed
# 2  1/3/2017           28          2
# 3  1/4/2017           24          7
# 4  1/5/2017           32          4

# %%
df.index[df.day == "1/4/2017"]
# Out:
# Index([3], dtype='int64')

# %%
index = df.index[df.day == "1/4/2017"][0]
index
# Out:
# 3

# %%
two_df = df[ ['day','event'] ]
two_df
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017   Snow
# 4  1/5/2017  Sunny
# 5  1/6/2017  Sunny

# %% [markdown]
# ## Operations On DataFrame

# %%
len (df[ df["temperature"] > 30])
# Out:
# 4

# %%
df['day'] [df['temperature']== df['temperature'].min()]
# Out:
# 3    1/4/2017
# Name: day, dtype: object

# %%
df['day'] [df['temperature']== df['temperature'].min()].to_list()[0]
# Out:
# '1/4/2017'

# %%
df['day'][df['temperature'] == df['temperature'].min()]
# Out:
# 3    1/4/2017
# Name: day, dtype: object

# %%
data = df.temperature.sort_values()
data
# Out:
# 3    24
# 2    28
# 5    31
# 0    32
# 4    32
# 1    35
# Name: temperature, dtype: int64

# %%
data = df.temperature.sort_values(ascending = False)
data
# Out:
# 1    35
# 0    32
# 4    32
# 5    31
# 2    28
# 3    24
# Name: temperature, dtype: int64

# %%
df['temperature'].mean()
# Out:
# 30.333333333333332

# %%
df['temperature'][3:6].mean() # Kinda doing SQL in pandas
# Out:
# 29.0

# %%
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
df['event'].max() # But mean() won't work since data type is string
# Out:
# 'Sunny'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
# get max occuring element
df.event.value_counts()
# Out:
# event
# Sunny    3
# Snow     2
# Rain     1
# Name: count, dtype: int64

# %%
df.event.value_counts().max()
# Out:
# 3

# %%
df.event.value_counts().idxmax()
# Out:
# 'Sunny'

# %%
df.event.value_counts().index[0]
# Out:
# 'Sunny'

# %%
df.event.value_counts()[0]
# Out:
# <ipython-input-77-8b991cd9777c>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.event.value_counts()[0]
# 3

# %%
df.event.mode()
# Out:
# 0    Sunny
# Name: event, dtype: object

# %%
print("Max Event : " + df.event.value_counts().index[0] + " and it occured " + str( df.event.value_counts()[0]) + " times" )
# Out:
# Max Event : Sunny and it occured 3 times
# <ipython-input-79-1c5e1e1f7589>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("Max Event : " + df.event.value_counts().index[0] + " and it occured " + str( df.event.value_counts()[0]) + " times" )

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %% [markdown]
# ## set_index

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index("day", inplace=True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4  Sunny
# 1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 3)

# %%
df.loc["1/1/2017" : "1/4/2017"]
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow

# %%
df.reset_index(inplace=True)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
df.set_index("day")
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4  Sunny
# 1/6/2017           31          2  Sunny

# %%
df.set_index("day", inplace=True)
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4  Sunny
# 1/6/2017           31          2  Sunny

# %%
df.reset_index(inplace=True)
df
# Out:
#    index       day  temperature  windspeed  event
# 0      0  1/1/2017           32          6   Rain
# 1      1  1/2/2017           35          7  Sunny
# 2      2  1/3/2017           28          2   Snow
# 3      3  1/4/2017           24          7   Snow
# 4      4  1/5/2017           32          4  Sunny
# 5      5  1/6/2017           31          2  Sunny

# %%
df.drop("index", axis = 1 , inplace= True)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
newdf = df.copy()
newdf = newdf.reset_index()
newdf.set_index("day", inplace=True)
newdf
# Out:
#           index  temperature  windspeed  event
# day
# 1/1/2017      0           32          6   Rain
# 1/2/2017      1           35          7  Sunny
# 1/3/2017      2           28          2   Snow
# 1/4/2017      3           24          7   Snow
# 1/5/2017      4           32          4  Sunny
# 1/6/2017      5           31          2  Sunny

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
newdf.reset_index(inplace=True)

# %%
newdf.set_index("event", inplace=True)
newdf
# Out:
#             day  index  temperature  windspeed
# event
# Rain   1/1/2017      0           32          6
# Sunny  1/2/2017      1           35          7
# Snow   1/3/2017      2           28          2
# Snow   1/4/2017      3           24          7
# Sunny  1/5/2017      4           32          4
# Sunny  1/6/2017      5           31          2

# %%
newdf.loc["Sunny"]
# Out:
#             day  index  temperature  windspeed
# event
# Sunny  1/2/2017      1           35          7
# Sunny  1/5/2017      4           32          4
# Sunny  1/6/2017      5           31          2

# %%
newdf.loc["Snow"]
# Out:
#             day  index  temperature  windspeed
# event
# Snow   1/3/2017      2           28          2
# Snow   1/4/2017      3           24          7

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4  Sunny
# 5  1/6/2017           31          2  Sunny

# %%
import numpy as np

df["NewData"] = np.arange(1,7) # [ 1,2,3,4,5,6]
df
# Out:
#         day  temperature  windspeed  event  NewData
# 0  1/1/2017           32          6   Rain        1
# 1  1/2/2017           35          7  Sunny        2
# 2  1/3/2017           28          2   Snow        3
# 3  1/4/2017           24          7   Snow        4
# 4  1/5/2017           32          4  Sunny        5
# 5  1/6/2017           31          2  Sunny        6

# %%
mylist = []
for i in df.temperature:
    if i == 32:
        mylist.append(True)
    else:
        mylist.append(False)
df["Check"] = mylist

# %%
df
# Out:
#         day  temperature  windspeed  event  NewData  Check
# 0  1/1/2017           32          6   Rain        1   True
# 1  1/2/2017           35          7  Sunny        2  False
# 2  1/3/2017           28          2   Snow        3  False
# 3  1/4/2017           24          7   Snow        4  False
# 4  1/5/2017           32          4  Sunny        5   True
# 5  1/6/2017           31          2  Sunny        6  False

# %%
import numpy as np
df["Names"] = np.array(["Nour", "Ali", "Omar" , "Emad" , "Anas" , "Amr" ])
df
# Out:
#         day  temperature  windspeed  event  NewData  Check Names
# 0  1/1/2017           32          6   Rain        1   True  Nour
# 1  1/2/2017           35          7  Sunny        2  False   Ali
# 2  1/3/2017           28          2   Snow        3  False  Omar
# 3  1/4/2017           24          7   Snow        4  False  Emad
# 4  1/5/2017           32          4  Sunny        5   True  Anas
# 5  1/6/2017           31          2  Sunny        6  False   Amr

# %%
df.reset_index(inplace=True)
df.drop("event", inplace=True, axis= 1)
df
# Out:
#    index       day  temperature  windspeed  NewData  Check Names
# 0      0  1/1/2017           32          6        1   True  Nour
# 1      1  1/2/2017           35          7        2  False   Ali
# 2      2  1/3/2017           28          2        3  False  Omar
# 3      3  1/4/2017           24          7        4  False  Emad
# 4      4  1/5/2017           32          4        5   True  Anas
# 5      5  1/6/2017           31          2        6  False   Amr

# %%
df.drop("index", inplace=True, axis = 1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
#df.reset_index(inplace=True)
df.set_index("temperature", inplace=True)

# %%
df
# Out:
#                   day  windspeed  NewData  Check Names
# temperature
# 32           1/1/2017          6        1   True  Nour
# 35           1/2/2017          7        2  False   Ali
# 28           1/3/2017          2        3  False  Omar
# 24           1/4/2017          7        4  False  Emad
# 32           1/5/2017          4        5   True  Anas
# 31           1/6/2017          2        6  False   Amr

# %%
df.loc[32]
# Out:
#                   day  windspeed  NewData  Check Names
# temperature
# 32           1/1/2017          6        1   True  Nour
# 32           1/5/2017          4        5   True  Anas

# %%
df.head()
# Out:
#                   day  windspeed  NewData  Check Names
# temperature
# 32           1/1/2017          6        1   True  Nour
# 35           1/2/2017          7        2  False   Ali
# 28           1/3/2017          2        3  False  Omar
# 24           1/4/2017          7        4  False  Emad
# 32           1/5/2017          4        5   True  Anas

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Sunny', 'Sunny']
}
df = pd.DataFrame(weather_data)
df.set_index('event',inplace=True) # this is kind of building a hash map using event as a key
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Sunny  1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Sunny  1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
df.to_string()
# Out:
# '            day  temperature  windspeed\nevent                                  \nRain   1/1/2017           32          6\nSunny  1/2/2017           35          7\nSnow   1/3/2017           28          2\nSnow   1/4/2017           24          7\nSunny  1/5/2017           32          4\nSunny  1/6/2017           31          2'

# %%
columns = []
data = dict()

num = int(input("please enter the number of columns: "))
while(num > 0):
    columns.append(input("please enter the column name: "))
    num -=1

for i in columns:
    data[i] = []

rows = int(input("please enter the number of rows: "))
while(rows > 0):
    for i in data:
        value = input(f"please enter the value of {i}: ")
        data[i].append(value)

    rows-=1
dataframe = pd.DataFrame(data)
dataframe
# Out:
# please enter the number of columns: 2
# please enter the column name: name
# please enter the column name: age
# please enter the number of rows: 2
# please enter the value of name: Nour
# please enter the value of age: 22
# please enter the value of name: 45000
# please enter the value of age: 11
#     name age
# 0   Nour  22
# 1  45000  11

# %%
dataframe["name"].dtype
# Out:
# dtype('O')

# %%
dataframe.age.dtype
# Out:
# dtype('O')

# %%
dataframe.age.astype(np.int8)
# Out:
# 0    22
# 1    11
# Name: age, dtype: int8

# %%
dataframe.Age = dataframe.age.astype(np.int16)
dataframe.Age.dtype
# Out:
# <ipython-input-121-806e26e2b0f8>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   dataframe.Age = dataframe.age.astype(np.int16)
# dtype('int16')
