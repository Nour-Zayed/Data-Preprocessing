# %% [markdown]
# ## Bar chart

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
lables = ["A", "B", "C"]
values = [1,4,2]
plt.figure(figsize=(6,4))
plt.bar(lables, values, color = "blue")
plt.yticks(np.arange(0,5,1))
plt.show()
# Out:
# <div id='c08383f9-2545-4459-83f8-fec8f9265bfb'></div>

# %%
lables = ["A", "B", "C"]
values = [1,4,2]
plt.figure(figsize=(6,4))
plt.bar(lables, values, color = "#8f285b", align= "edge")
plt.yticks(np.arange(0,5,1))
plt.show()

# %%
names = ["Ahmed", "Nour", "Mostafa"]
salary = [1200,2400,2145]
plt.figure(figsize=(6,4))
plt.bar(names, salary, color = "blue", width = 0.3)
plt.show()

# %%
lables = ["Ahmed", "Nour", "Sohila"]
values = [1,4 ,2]
plt.figure(figsize=(6,4))
plt.bar(lables, values, width= .3, color = "#5f385b")
plt.xticks(rotation = 45)
plt.yticks(np.arange(0,5,1))
plt.show()

# %%
lables = ["Ahmed", "Nour", "Sohila"]
values = [1,4 ,2]
plt.figure(figsize=(6,4))
plt.bar(lables, values, width= .3, color = "#5f385b")
plt.xticks(rotation = 90)
plt.yticks(np.arange(0,5,1))
plt.show()

# %%
lables = ["A", "B", "C"]
values = [1,4 ,2]
plt.figure(figsize=(6,4))
plt.bar(lables, values, width= .3, color = "#5f385b")
plt.yticks(np.arange(0,5,1))
plt.show()

# %%
names = []
salaries = [ ]

for i in range(5):
    name = input("please enter your name: ")
    sal  = int(input("please enter your salary: "))
    names.append(name)
    salaries.append(sal)
# Out:
# please enter your name: Nour
# please enter your salary: 15000
# please enter your name: Ali
# please enter your salary: 30000
# please enter your name: Aya
# please enter your salary: 15000
# please enter your name: Samar
# please enter your salary: 20000
# please enter your name: Ahmed
# please enter your salary: 40000

# %%
salaries
# Out:
# [15000, 30000, 15000, 20000, 40000]

# %%
plt.rcParams["figure.figsize"] = (10, 4)
plt.bar(names, salaries, width= 0.4)
plt.show()

# %%
plt.rcParams["figure.figsize"] = (8, 3)
plt.bar(names, salaries, width= 0.4)
plt.show()

# %%
plt.rcParams["figure.figsize"] = (6, 4)
names = []
salaries = [ ]

for i in range(5):
    name = input("please enter your name: ")
    sal  = int(input("please enter your salary: "))
    names.append(name)
    salaries.append(sal)

plt.bar(names, salaries, width= 0.4)
plt.show()
# Out:
# please enter your name: Nour
# please enter your salary: 15000
# please enter your name: Aya
# please enter your salary: 40000
# please enter your name: Samar
# please enter your salary: 3000
# please enter your name: Ahmed
# please enter your salary: 140000000000000000
# please enter your name: ALi
# please enter your salary: 1500

# %%
lables = ["A", "B", "C"]
values = [1,4 ,2]
bars = plt.bar(lables, values, color = "#034dad")
bars[0].set_hatch('/')
bars[1].set_hatch('o')
bars[2].set_hatch('*')
plt.show()

# %%
lables = ["A", "B", "C"]
values = [1,4 ,2]
bars = plt.bar(lables, values, color = ["red", "Green", "blue"], width = 0.2 )
bars[0].color = "Black"
bars[1].set_hatch('o')
bars[2].set_hatch('*')
plt.show()

# %%
lables = ["A", "B", "C"]
values = [1,4 ,2]
plt.bar(lables, values, color = "#034dad")[1].set_hatch("/")
plt.show()

# %%
lables = ["A", "B", "C"]
values = [1,4 ,2]
bars = plt.bar(lables, values)
bars[0].set_hatch('o')
plt.show()

# %%
lables = ["A", "B", "C"]
values = [1,4 ,2]
bars = plt.bar(lables, values , color = "#8f285b")
patterns = ['/', 'o', '*']
for bar in plt.bar(lables, values):
    bar.set_hatch(patterns.pop(0))
plt.show()

# %%
lables = ["A", "B", "C"]
values = [1,4 ,2]
bars = plt.bar(lables, values)
patterns = ['/', 'o', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))
plt.show()

# %%
lables = ["A", "B", "C"]
values = [1,4 ,2]
bars = plt.bar(lables, values)
patterns = ['/', 'o', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))
plt.show()

# %%
#here
lables = ["A", "B", "C"]
values = [1,4 ,2]
bars = plt.bar(lables, values)
patterns = ['/', 'o', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))
plt.show()

# %%
x = [1,2,4,5,6]
y = [2,4,8,10,12]
plt.plot(x,y,color='blue',marker='o',linestyle='')
plt.grid(True)
plt.show()

# %%
plt.plot(x,y,'b<',alpha=.4) # alpha can be specified on a scale 0 to 1
plt.show()

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,40]
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")
plt.legend()
plt.show()

# %%
# Legend at different location with shadow enabled and fontsize set to large
plt.ioff()
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.legend(shadow=True,fontsize='medium')

plt.show()

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center')

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,85,27]



plt.bar(company,revenue, label="Revenue")
addlabels(company, revenue)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,85,27]
profit=[40,7,34,12]
xpos = np.arange(len(company)) # numpyarray : 0 , 1 , 2, 3

plt.bar(company,revenue, width=0.4, label="Revenue") # x = 0, x = 0.4
plt.bar(xpos-0.4,profit, width=0.4,label="Profit")# x = -.4  , x = 0
# 0 - 0.4 = -.4 , .6 , 1.6 , 2.6
plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,85,27]
profit=[40,7,34,12]
xpos = np.arange(len(company)) # numpyarray : 0 , 1 , 2, 3

plt.bar(company,revenue, width=0.4, label="Revenue") # x = 0, x = 0.4
plt.bar(xpos-0.4,profit, width=0.3,label="Profit")# x = -.4  , x = 0
# 0 - 0.4 = -.4 , .6 , 1.6 , 2.6
plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()
plt.show()

# %%
40/90
# Out:
# 0.4444444444444444

# %%
12/27
# Out:
# 0.4444444444444444

# %%
plt.figure(figsize=(8,6))
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,85,27]
profit=[40,7,34,12]
xpos = np.arange(len(company)) # numpyarray : 0 , 1 , 2, 3

plt.bar(company,revenue, width=0.4, label="Revenue") # x = 0, x = 0.4
plt.bar(company,profit, width=0.4,label="Profit")# x = -.4  , x = 0
# 0 - 0.4 = -.4 , .6 , 1.6 , 2.6
plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
company=['GOOGL','AMZN','MSFT','FB']
xp = [0, 1, 2,3]
revenue=[90,136,85,27]
profit=[40,7,34,12]
xpos = np.arange(len(company)) # numpyarray : 0 , 1 , 2, 3

plt.bar(xpos,revenue, width=0.6, label="Revenue") # x = 0, x = 0.4
plt.bar(xpos-0.4,profit, width=0.3,label="Profit")# x = -.4  , x = 0
# 0 - 0.4 = -.4 , .6 , 1.6 , 2.6
plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()
plt.show()

# %% [markdown]
# ## pie chart

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# pie chart
exp_vals = [1400,600,300,300,250] #expenses
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car","Other Utilities"]
plt.pie(exp_vals,labels=exp_labels)
plt.show()

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, autopct='%0.0f%%',radius=2.0 )
plt.show()

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, autopct='%0.4f%%',radius=2.0 )
plt.show()

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, autopct='%1.2f%%' )
plt.show()

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.4f%%',radius=1.75,explode=[0,0,0.5,0,0])
plt.show() # formatting

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode=[0.1,0.3,0.1,0.1,0.1])
plt.legend(bbox_to_anchor =(1.1, 1))
plt.show()
